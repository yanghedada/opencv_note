# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# 使用函数 cv2.imread() 读入图像。这幅图像应该在此程序的工作路径，或者给函数提供完整路径，
# 第二个参数是要告诉函数应该如何读取这幅图片。
#
# • cv2.IMREAD_COLOR：读入一副彩色图像。图像的透明度会被忽略，
# 这是默认参数。
#
# • cv2.IMREAD_GRAYSCALE：以灰度模式读入图像
#
# cv2.IMREAD_UNCHANGED：读入一幅图像，并且包括图像的 alpha 通道

# %%
#cv2.IMREAD_COLOR
#cv2.IMREAD_GRAYSCALE
#cv2.IMREAD_UNCHANGED
img = cv2.imread('1.jpg',cv2.IMREAD_COLOR)

# %%
img = cv2.imread('1.jpg',cv2.IMREAD_COLOR)
img.shape
# Out:
# (220, 308, 3)

# %%
img = cv2.imread('1.jpg',cv2.IMREAD_GRAYSCALE)
img.shape
# Out:
# (220, 308)

# %%
img = cv2.imread('1.jpg',cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (220, 308, 3)

# %%
print(type(img), img.shape)
# Out:
# <class 'numpy.ndarray'> (220, 308, 3)

# %% [markdown]
# 使用函数 cv2.imshow() 显示图像。窗口会自动调整为图像大小。第一
# 个参数是窗口的名字，其次才是我们的图像。你可以创建多个窗口，只要你喜
# 欢，但是必须给他们不同的名字

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
#cv2.destroyAllWindows()
cv2.destroyWindow('image')

# %% [markdown]
# 先 创 建 一 个 窗 口， 之 后
# 再 加 载 图 像。 这 种 情 况 下， 你 可 以 决 定 窗 口 是 否 可 以 调 整
# 大 小。 使 用 到 的 函 数 是 cv2.namedWindow()。 初 始 设 定 函 数
# 标 签 是 cv2.WINDOW_AUTOSIZE。 但 是 如 果 你 把 标 签 改 成
# cv2.WINDOW_NORMAL，你就可以调整窗口大小了。当图像维度太大，
# 或者要添加轨迹条时，调整窗口大小将会很有用

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for i in ['1.jpg', '2.jpg', '3.jpg']:
    img = cv2.imread(i, cv2.IMREAD_COLOR)
    cv2.imshow(i, img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('4.jpg', img)
# Out:
# True

# %%
img = cv2.imread('1.jpg',1)
img.shape
# Out:
# (220, 308, 3)

# %%
#BGR模式
import matplotlib.pyplot as plt
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#RGB模式
import matplotlib.pyplot as plt
b,g, r = cv2.split(img)
img2 = cv2.merge([r,g,b])
#img2 = img[:,:,::-1]
#img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# 用摄像头捕获视频m
#
# cap.read() 返回一个布尔值（True/False）。如果帧读取的是正确的，
# 就是 True。所以最后你可以通过检查他的返回值来查看视频文件是否已经到
# 了结尾。
# 有时 cap 可能不能成功的初始化摄像头设备。这种情况下上面的代码会报
# 错。你可以使用 cap.isOpened()，来检查是否成功初始化了。如果返回值是
# True，那就没有问题。否则就要使用函数 cap.open()。

# %%
cap = cv2.VideoCapture(0)
#print(cap.isOpened())
cap.open(0)
while (True):
    ret, frame = cap.read()
    if ret:
        # cv2.COLOR_BGR2GRAY
        # cv2.COLOR_BGR2HSV
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
        
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break   
#  使用 cap.get(3) 和 cap.get(4) 来查看每一帧的宽和高
print(cap.get(3),cap.get(4)) 
cap.release()
cv2.destroyAllWindows()
# Out:
# 640.0 480.0

# %% [markdown]
# 读取视频文件Mm

# %%
#读取视频文件Mm

cap = cv2.VideoCapture('test.avi')
cvtColor =   False# True
while(cap.isOpened()):
    ret, frame = cap.read()
    
    if cvtColor:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# 保存视频

# %%
cap = cv2.VideoCapture(0)
# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame = cv2.flip(frame,0)
        # write the flipped frame
        out.write(frame)
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# 创建 img 图片，注意数据格式为 np.uint8;

# %%
img = np.zeros((512, 512, 3), np.uint8)
img = cv2.imread('1.jpg',1)
img2 = cv2.line(img, (0,0),(511, 511),(255,0,0),5)
# cv2.imshow('image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img = cv2.imread('1.jpg',1)
img2 = cv2.rectangle(img,(0,0),(20,12),(255,0,0),3)
# cv2.imshow('image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img = cv2.imread('1.jpg',1)
img2 = cv2.circle(img,(100,10), 100, (0,0,255), -1)
# cv2.imshow('image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# 一个参数是中心点的位置坐标。
# 下一个参数是长轴和短轴的长度。椭圆沿逆时针方向旋转的角度。椭圆弧演
# 顺时针方向起始的角度和结束角度，如果是 0 很 360，就是整个椭圆。查

# %%
img = cv2.imread('1.jpg',1)
img2 = cv2.ellipse(img,(100,100),(100,50),0,0,360,255,-1)
# cv2.imshow('image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#画多边形#

img = cv2.imread('1.jpg',1)
pts=np.array([[30,40],[20,30],[70,20],[70,10]], np.int32)
pts=pts.reshape((-1,1,2))
# 这里 reshape 的第一个参数为-1, 表明这一维的长度是根据后面的维度的计算出来的。
#如果第三个参数是 False，我们得到的多边形是不闭合的（首尾不相连）
img2 = cv2.polylines(img,[pts],True,(0,255,255))
# cv2.imshow('image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# 要在图片上绘制文字，你需要设置下列参数：
#
# • 你要绘制的文字
#
# • 你要绘制的位置
#
# • 字体类型（通过查看 cv2.putText() 的文档找到支持的字体）
#
# • 字体的大小
#
# • 文字的一般属性如颜色，粗细，线条的类型等。为了更好看一点推荐使用
#
# linetype=cv2.LINE_AA

# %%
img = cv2.imread('1.jpg',1)
font=cv2.FONT_HERSHEY_SIMPLEX
img2 = cv2.putText(img,'OpenCV',(100,100), font, 1,(255,255,255),2,cv2.LINE_AA)
# cv2.imshow('image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img = cv2.imread('1.jpg')

# %%
img.shape
# Out:
# (300, 533, 3)

# %%
px=img[100,100]
blue=img[100,100,0]

# %%
img.item(10,10,2)
# Out:
# 216

# %%
img.itemset((10, 10, 2),100)

# %%
img.item(10,10,2)
# Out:
# 100

# %%
img.size
# Out:
# 479700

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (300, 533, 3)

# %%
plt.imshow(img)
plt.show()

# %%
nose = np.random.randn(50,50,3)
img[100:150,100:150,:] = nose
plt.imshow(img)
plt.show()

# %%
img = cv2.imread('1.jpg')
b, g, r = cv2.split(img)
#img = cv2.merge(, r)
#img = cv2.merge(img, r)

# %%
img.shape, b.shape
# Out:
# ((300, 533, 3), (300, 533))

# %%
plt.imshow(r)
plt.show()

# %% [markdown]
# # 为图像扩边（填充）如果你想在图像周围创建一个边，就像相框一样，你可以使用 cv2.copyMakeBorder()
# 函数。这经常在卷积运算或 0 填充时被用到。
# 如果你想在图像周围创建一个边，就像相框一样，你可以使用 cv2.copyMakeBorder()
# 函数。这经常在卷积运算或 0 填充时被用到。这个函数包括如下参数：
# • src 输入图像
# • top, bottom, left, right 对应边界的像素数目。
# • borderType 要添加那种类型的边界，类型如下
# – cv2.BORDER_CONSTANT 添加有颜色的常数值边界，还需要
# 下一个参数（value）。
# – cv2.BORDER_REFLECT 边界元素的镜像。比如: fedcba|abcdefgh|hgfedcb
# – cv2.BORDER_REFLECT_101 or cv2.BORDER_DEFAULT
# 跟上面一样，但稍作改动。例如: gfedcb|abcdefgh|gfedcba
# – cv2.BORDER_REPLICATE 重复最后一个元素。

# %%
BLUE=[255,0,0]
img1=cv2.imread('1.jpg')
replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()

# %% [markdown]
# 图像上的算术运算
#
# cv2.add()， cv2.addWeighted()
#
# OpenCV 的加法是一种饱和操作，而 Numpy 的加法是一种模操作。

# %%
x = np.uint8([250])
y = np.uint8([10])
cv2.add(x, y)
# Out:
# array([[255]], dtype=uint8)

# %% [markdown]
# 图像混合

# %%
img1=cv2.imread('1.jpg')
img1=cv2.resize(img1,(300,200),interpolation=cv2.INTER_CUBIC)
img2=cv2.imread('2.jpg')
img2=cv2.resize(img2,(300,200),interpolation=cv2.INTER_CUBIC)
print(img1.shape, img2.shape)
# Out:
# (200, 300, 3) (200, 300, 3)

# %%
img1=cv2.imread('1.jpg')
img1=cv2.resize(img1,(300,200),interpolation=cv2.INTER_CUBIC)
img2=cv2.imread('2.jpg')
img2=cv2.resize(img2,(300,200),interpolation=cv2.INTER_CUBIC)
print(img1.shape, img2.shape)

dst=cv2.addWeighted(img1,0.5,img2,0.5,0)
#cv2.imshow('dst',dst)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.subplot(311)
plt.imshow(img1)
plt.xticks([])
plt.yticks([])

plt.subplot(312)
plt.imshow(img2)
plt.xticks([])
plt.yticks([])

plt.subplot(313)
plt.imshow(dst)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# (200, 300, 3) (200, 300, 3)

# %% [markdown]
# 图像的位操作：图像与运算cv2.bitwise_and，图像或运算cv2.bitwise_or，图像非运算cv2.bitwise_not与图像异或运算cv2.bitwise_xor。
#
# 1）图像与运算-cv2.bitwise_and(src1, src2, dst=None, mask = None)
#
# 2）图像或运算-cv2.bitwise_or(src1, src2, dst=None, mask = None)
#
# 3）图像非运算-cv2.bitwise_not(src1, src2, dst=None, mask = None)
#
# 图像非运算的效果：一个二值图，将黑色转为白色，白色转为黑色。
#
# 4) 图像异或运算-cv2.bitwise_xor(src1, src2, dst=None, mask = None)
#
# 这四个运算，最少要有两个参数，即src1,src2；dst：参数返回结果可选，mask：参数也是可选的，指定msk区域进行操作。

# %%
img2=cv2.imread('rio.jpg')
img2.shape
# Out:
# (100, 100, 3)

# %%
img_0 = np.zeros((100,100,3),np.uint8) 
img_255 = np.zeros((100,100,3),np.uint8) + 255
plt.subplot(211)
plt.imshow(img_0)
plt.subplot(212)
plt.imshow(img_255)
plt.show()

# %%
img1=cv2.imread('1.jpg')
#img1 = cv2.resize(img1,(300,200),interpolation=cv2.INTER_CUBIC)
img2=cv2.imread('rio.jpg')
#img2= cv2.resize(img2,(300,200),interpolation=cv2.INTER_CUBIC)
img3 = img1.copy()



rows,cols,channels = img2.shape
img3[0:rows, 0:cols ] = img2
roi = img1[0:rows, 0:cols ]
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 175, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

# Now black-out the area of logo in ROI
# 取 roi 中与 mask 中不为零的值对应的像素的值，其他值为 0
# 注意这里必须有 mask=mask 或者 mask=mask_inv, 其中的 mask= 不能忽略
#从roi里面抠出一个LOGO的轮廓：


# 怎么抠图 ，背景一般是255，既白色，图片的像素值没有白色高。
# 当mask把logo的图形变成0, 当某颜色与0 and操作为0，就是黑色。
# 一般是有两个mask，mask1上 = logo部分为255，一个用来在logo图片上and出logo图片，只有logo凸出
#  另外一个是在水印图片上，mask2上 = logo 部分值为0， 在水印图片and出一个凹坑
# 两个图片add正好填充
img1_bg = cv2.bitwise_and(roi,roi,mask = mask)

# 取 roi 中与 mask_inv 中不为零的值对应的像素的值，其他值为 0。
# Take only region of logo from logo image.
#从第二幅图里面抠出LOGO标志
# 
img2_fg = cv2.bitwise_and(img2,img2,mask = mask_inv)
# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img_roi = img1.copy()
img_roi[0:rows, 0:cols ] = dst
# cv2.imshow('res',img1)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.figure(figsize=(16,4))
plt.subplot(141)
plt.imshow(img1)


plt.subplot(142)
plt.imshow(img2)


plt.subplot(143)
plt.imshow(img_roi)

plt.subplot(144)
plt.imshow(img3)

plt.show()

# %% [markdown]
# Hsv 跟踪对象

# %%
cap=cv2.VideoCapture(0)
while(1):
    # 获取每一帧
    ret,frame=cap.read()
    # 转换到 HSV
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    # 设定蓝色的阈值
    lower_blue=np.array([110,50,50])
    upper_blue=np.array([130,255,255])
    # 根据阈值构建掩模
    # 只有在蓝色的范围内的值为255， 不在蓝色范围内的值为0。
    # 255为白色，会and出所有的颜色。0为黑色不会and出任何颜色。
    mask=cv2.inRange(hsv,lower_blue,upper_blue)
    # 对原图像和掩模进行位运算
    res=cv2.bitwise_and(frame,frame,mask=mask)
    # 显示图像
    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    k=cv2.waitKey(5)&0xFF
    if k==27:
        break
# 关闭窗口
cap.release()
cv2.destroyAllWindows()

# %%
green=np.uint8([[[0,255,0]]])
hsv_green=cv2.cvtColor(green,cv2.COLOR_BGR2HSV)
hsv_green
# Out:
# array([[[ 60, 255, 255]]], dtype=uint8)

# %%
img = cv2.imread('1.jpg')
img.shape
# Out:
# (220, 308, 3)

# %% [markdown]
# 扩展缩放
#
# 在缩放时我们推荐使用 cv2.INTER_AREA，
#
# 在扩展时我们推荐使用 v2.INTER_CUBIC（慢) 和 v2.INTER_LINEAR。

# %%
res = cv2.resize(img,None,fx=2,fy=2,interpolation=cv2.INTER_CUBIC)
res.shape
# Out:
# (440, 616, 3)

# %% [markdown]
# 0x03. 缩放图片

# %%
img = cv2.imread('1.jpg')
height,width=img.shape[:2]
res=cv2.resize(img,(2*width,2*height),interpolation=cv2.INTER_CUBIC)
img.shape, res.shape


# img = cv2.imread('messi5.jpg')
# res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

# #OR

# height, width = img.shape[:2]
# res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)
# Out:
# ((220, 308, 3), (440, 616, 3))

# %%
# while(1):
#     cv2.imshow('res',res)
#     cv2.imshow('img',img)
#     if cv2.waitKey(1) & 0xFF == 27:
#         break
# cv2.destroyAllWindows()
plt.figure(figsize=(8,4))
plt.subplot(211)
plt.imshow(img)
plt.subplot(212)
plt.imshow(res)
plt.show()

# %% [markdown]
# 图像平移

# %%
img = cv2.imread('1.jpg',0)
rows,cols = img.shape
#被移动 （100,50）个像素
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))
plt.imshow(dst)
plt.show()

# %%
#旋转

img = cv2.imread('1.jpg')
rows,cols = img.shape
## 这里的第一个参数为旋转中心，第二个为旋转角度，第三个为旋转后的缩放因子
# 可以通过设置旋转中心，缩放因子，以及窗口大小来防止旋转后超出边界的问题
#旋转矩阵
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
# 第三个参数是输出图像的尺寸中心
dst = cv2.warpAffine(img,M,(cols,rows))
plt.imshow(dst)
plt.show()

# %% [markdown]
# 仿射变换
#
# 原图中所有的平行线在结果图像中同样平行
#
# cv2.getAffineTransform 会创建一个 2x3 的矩阵，最后这个矩阵会被传给函数 cv2.warpAffine。

# %%
img=cv2.imread('1.jpg')
rows,cols,ch=img.shape
pts1=np.float32([[50,50],[200,50],[50,200]])
pts2=np.float32([[10,100],[200,50],[100,250]])
M=cv2.getAffineTransform(pts1,pts2)
dst=cv2.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img=cv2.imread('1.jpg')
rows,cols,ch=img.shape
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M=cv2.getPerspectiveTransform(pts1,pts2)
dst=cv2.warpPerspective(img,M,(300,300))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
# 
img=cv2.imread('1.jpg',0)
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
print(ret, thresh1.shape)
# Out:
# 127.0 (220, 308)

# %%
#对一副双峰图像自动根据其直方图计算出一个阈值ret2
#然后算法会找到最优阈值，这个最优阈值就是返回值 retVal。
# 如果不使用 Otsu 二值化，返回的retVal 值与设定的阈值相等
img=cv2.imread('1.jpg',0)
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
print(ret2, th2.shape)
# Out:
# 137.0 (220, 308)

# %%
#简单阈值
img=cv2.imread('1.jpg',0)
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3=cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4=cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5=cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# Adaptive Method- 指定计算阈值的方法。
#
# – cv2.ADPTIVE_THRESH_MEAN_C：阈值取自相邻区域的平
# 均值
#
#
# – cv2.ADPTIVE_THRESH_GAUSSIAN_C：阈值取值相邻区域
# 的加权和，权重为一个高斯窗口。
#
# • Block Size - 邻域大小（用来计算阈值的区域大小）。
#
#
# • C - 这就是是一个常数，阈值就等于的平均值或者加权平均值减去这个常
# 数

# %%
# 自适应阈值
img = cv2.imread('1.jpg',0)
# 中值滤波
img = cv2.medianBlur(img,5)
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
#11 为 Block size, 2 为 C 值
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
cv2.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
